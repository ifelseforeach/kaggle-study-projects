# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./data/train.csv')

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
s_3c_m=(df['Pclass']==3) & (df['Sex']=='male') & (df['SibSp']==0) & (df['Parch']==0)
s_3c_m.head(5)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
s_3c_m_mean_age = round(df[s_3c_m]['Age'].mean())
s_3c_m_mean_age1`-
# Out:
# 29.0

# %%
m3c_df=df[s_3c_m]

# %%
df.drop(index=m3c_df.index, inplace=True)

# %%
df =pd.concat([df, m3c_df])

# %%
df.reset_index().head(5)
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0      0            1         0       3
# 1      1            2         1       1
# 2      2            3         1       3
# 3      3            4         1       1
# 4      6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df[df['Age'].isnull()].head(6)
# Out:
#     PassengerId  Survived  Pclass  \
# 17           18         1       2
# 19           20         1       3
# 28           29         1       3
# 31           32         1       1
# 32           33         1       3
# 46           47         0       3
#
#                                               Name     Sex  Age  SibSp  Parch  \
# 17                    Williams, Mr. Charles Eugene    male  NaN      0      0
# 19                         Masselmani, Mrs. Fatima  female  NaN      0      0
# 28                   O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0      0
# 31  Spencer, Mrs. William Augustus (Marie Eugenie)  female  NaN      1      0
# 32                        Glynn, Miss. Mary Agatha  female  NaN      0      0
# 46                               Lennon, Mr. Denis    male  NaN      1      0
#
#       Ticket      Fare Cabin Embarked
# 17    244373   13.0000   NaN        S
# 19      2649    7.2250   NaN        C
# 28    330959    7.8792   NaN        Q
# ...

# %%
s_3c_f=(df['Pclass']==3) & (df['Sex']=='female') & (df['SibSp']==0) & (df['Parch']==0)

s_3c_f_mean_age = round(df[s_3c_f]['Age'].mean())
s_3c_f_mean_age
# Out:
# 24.0

# %%
f3c_df=df[s_3c_f]

# %%
f3c_df.fillna(s_3c_f_mean_age,inplace=True)

# %%
df.drop(index=f3c_df.index, inplace=True)

# %%
df =pd.concat([df, f3c_df])

# %%
df[df['Age'].isnull()].head(6)
# Out:
#     PassengerId  Survived  Pclass  \
# 17           18         1       2
# 31           32         1       1
# 46           47         0       3
# 48           49         0       3
# 55           56         1       1
# 64           65         0       1
#
#                                               Name     Sex  Age  SibSp  Parch  \
# 17                    Williams, Mr. Charles Eugene    male  NaN      0      0
# 31  Spencer, Mrs. William Augustus (Marie Eugenie)  female  NaN      1      0
# 46                               Lennon, Mr. Denis    male  NaN      1      0
# 48                             Samaan, Mr. Youssef    male  NaN      2      0
# 55                               Woolner, Mr. Hugh    male  NaN      0      0
# 64                           Stewart, Mr. Albert A    male  NaN      0      0
#
#       Ticket      Fare Cabin Embarked
# 17    244373   13.0000   NaN        S
# 31  PC 17569  146.5208   B78        C
# 46    370371   15.5000   NaN        Q
# ...

# %%
by_name = df['Name']

# %%
def miss(var):
    if 'Miss' in var:
        return True
    else:
        return False

# %%
df[(by_name.apply(miss)) & (df['Age']<16)]['Age'].count()
# Out:
# 41
